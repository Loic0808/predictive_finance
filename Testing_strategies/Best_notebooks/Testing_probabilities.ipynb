# %%
import numpy as np
import pandas as pd
import yfinance as yf
import tensorflow as tf
import matplotlib.pyplot as plt

from scipy import linalg
from scipy.stats import norm

from sklearn import linear_model

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# 2025-03-13 19:27:02.674937: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Let $\tau$ represent some time period for which we want to know the return of a stock price $(S_t)_{t \geq 0}$. We assume that $(S_t)_{t \geq 0}$ follows a geometric Brownian motion, i.e.
# $$ dS_t = \mu S_t dt + \sigma S_t dW_t,$$
# where $(W_t)_{t \geq 0}$ is a Brownian motion. The explicit solution is given by
# $$ S_t = S_0 \text{exp}\left( \left( \mu - \frac{\sigma^2}{2} \right)t + \sigma W_t \right).$$
# Calculating $S_t/S_{t - \tau}$, we easily find for a given return $r$
# \begin{align*}
#     \mathbb{P}\left( \frac{S_t}{S_{t-\tau}} > r \right) &= \mathbb{P}\left( \left( \mu - \frac{\sigma^2}{2} \right)\tau + \sigma*\sqrt{\tau}X > \log(r) \right)\\
#     &= \mathbb{P}\left( X > \frac{1}{\sigma*\sqrt{\tau}} \left(\log(r) + \left(\frac{\sigma^2}{2} - \mu \right)\tau\right) \right),
# \end{align*}
# for $X \sim \mathcal{N}(0,1)$.

# %%
mu = 0.005 # drift in %
sigma = 0.023 # volatility in %
tau = 20 # number of days
r = 1.08 # return over tau days

RH = 1/(np.sqrt(tau)*sigma)*(np.log(r) + (sigma**2/2 - mu)*tau)

prob = norm.sf(RH, loc=0, scale=1)

print(prob)
# Out:
# 0.5684997775741911

# %% [markdown]
# We compare the theoretical results with actual stock prices

# %%
ticker = "GOOG"
start_date = "2015-01-05"
end_date = "2025-01-01"

data = yf.download(tickers = ticker, start=start_date, end=end_date)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
data['log_return'] = np.log(data['Close'] / data['Close'].shift(1)) # we calculate the log returns
data.dropna(inplace=True)

# Since we have daily data, we calculate the daily drift and volatility. If we want it for a year we multiply mu by 252 and sigma by sqrt(252)
mu_data = data['log_return'].mean() # This representy the mean daily drift
sigma_data = data['log_return'].std()

print(mu_data, sigma_data)
# Out:
# 0.0007992949491225349 0.017917049420138206

# %%
last_month_data = data[-tau:]
last_month_data['log_return_short'] = np.log(last_month_data['Close'] / last_month_data['Close'].shift(1))
last_month_data.dropna(inplace=True)

mu_last_month = last_month_data['log_return_short'].mean()
sigma_last_month = last_month_data['log_return_short'].std()

print(mu_last_month, sigma_last_month)
# Out:
# 0.005108624006035792 0.02305654055639354
# /var/folders/6b/r3xhr4d94wn52lq9yxzbnnzm0000gn/T/ipykernel_13307/2606001156.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_month_data['log_return_short'] = np.log(last_month_data['Close'] / last_month_data['Close'].shift(1))
# /var/folders/6b/r3xhr4d94wn52lq9yxzbnnzm0000gn/T/ipykernel_13307/2606001156.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_month_data.dropna(inplace=True)

# %%
print(data["Close"].iloc[-1, 0]/data["Close"].iloc[0, 0])
print(last_month_data["Close"].iloc[-1, 0]/last_month_data["Close"].iloc[0, 0])
# Out:
# 7.636027193050291
# 1.082719365463327

# %% [markdown]
# What we can conclude is that the geometric Brownian motion model is not optimal and/or the volatility and drift neither, since the theoretical result only coincides with the observed results if the time period $\tau$ is small (where we can then assume $\mu$ and $\sigma$ constant). For larger time periods $\tau$, the results differe strongly.

# %%
tickers = ["AAPL", "MSFT", "AMZN", "NVDA", "JPM", "TSLA"]

data_extended = yf.download(tickers, start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
# First row of google stock is droped because the log returns column contains NaN
data_extended = data_extended.iloc[1:]

# %%
plt.figure(figsize=(10, 5))  
plt.plot(data.index, data['Close'], label='Google', color='blue')
plt.plot(data.index, data_extended["Close"]["AMZN"], label='Amazon', color='orange')
plt.plot(data.index, data_extended["Close"]["JPM"], label='JPM', color='black')
plt.plot(data.index, data_extended["Close"]["AAPL"], label='Apple', color='grey')
plt.plot(data.index, data_extended["Close"]["NVDA"], label='Nvidia', color='green')
plt.plot(data.index, data_extended["Close"]["TSLA"], label='Tesla', color='red')
plt.plot(data.index, data_extended["Close"]["MSFT"], label='Microsoft', color='purple')

# Formatting
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.title('Time Series Plot')
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# Now we simulate the path of a geometric Brownian motion using the explicit form and the differential form.

# %%
timehorizon = 10 # years
timesteps = len(data.index.to_list())
S_0 = np.array([data["Close"].iloc[0, 0]])

mu_plot = 0.1
sigma_plot = 0.2

BMpath = [np.zeros(1)]
GBM_SDE = [S_0]
GBM_explicit = [S_0]

for i in range(1, timesteps):
    helper = np.random.normal(0,np.sqrt(timehorizon/timesteps),1)
    BMpath = BMpath + [BMpath[-1]+helper]
    increment = mu_plot*GBM_SDE[-1]*timehorizon/timesteps + sigma_plot*GBM_SDE[-1]*helper
    GBM_SDE = GBM_SDE + [GBM_SDE[-1] + increment]
    GBM_explicit = GBM_explicit + [S_0*np.exp((mu_plot-sigma_plot**2/2)*i*timehorizon/timesteps + sigma_plot*BMpath[-1])]

# %%
plt.figure(figsize=(10, 5))  
plt.plot(data.index.to_list(), GBM_explicit, label='GBM using explicit formular', color='red') # np.linspace(0, 2501, 2500)
plt.plot(data.index.to_list(), GBM_SDE, label='GBM using SDE', color='blue')

# Formatting
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.title('Time Series Plot')
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# We try to recover the underlying Brownian motion from the GBM. Using the explicit description of $(S_t)_{t \geq 0}$, we get
# $$ W_t = \frac{1}{\sigma} \left(\log\left( \frac{S_t}{S_0}\right) + \left(\frac{\sigma^2}{2} - \mu\right)t \right).$$

# %%
times = [np.array([i/timesteps*timehorizon], dtype=float) for i in range(timesteps)]
recovered_BM = 1/(sigma_plot)*(np.log(GBM_explicit/S_0) + np.array((sigma_plot**2/2 - mu_plot), dtype=float)*times)

plt.figure(figsize=(10, 5))  
plt.plot(data.index.to_list(), BMpath, label='Original BM', color='red')
plt.plot(data.index.to_list(), recovered_BM, label='BM recovered from price process', color='blue')

# Formatting
plt.xlabel('Time')
plt.ylabel('Closing Price')
plt.title('Time Series Plot')
plt.legend()
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# In the following we will train a machine learning model which will learn the stochastic differential equation of some stock prices. Then we will simulate many Brownian motions and predict the corresponding prices to see if we are able to draw some conclusions.

# %%
# First we calculate the underlying Brownian motion of the Google stock price process. We assume to work under the Black-Scholes model,
# i.e., with a geometric Brownian motion, but with non-constant drift and volatility.

# .rolling(30): Creates a rolling window of size 30 (i.e., a moving window that includes 30 past values at each step).
Omega = (data["log_return"]
         .rolling(30)
         .cov()
         .dropna())

# dates from start_time to end_time
dates = data["log_return"].index

# For the 30 first days we do not have a variance, so we ignore them
dates = dates[30:]

# Creates a dictionnary with keyes being the dates and values given by the rolling variance of the past 30 days
covdata = dict(zip(dates, [Omega.loc[date] for date in dates]))

marketBM = dict(zip(dates, [1/ np.sqrt(Omega.loc[date]) * data["log_return"].loc[date] for date in dates]))

# %% [markdown]
# Up to here, the marketBM variable represents the following
# $$ \frac{1}{\sqrt{\sigma_t}} \log\left(\frac{S_t}{S_{t-1}}\right),$$
# where $\sigma_t$ is the variance over the last 30 days.

# %%
plt.plot([marketBM[date] for date in dates])
plt.show()
print(np.std(np.array([marketBM[date] for date in dates])))
print(np.mean(np.array([marketBM[date] for date in dates])))
# Out:
# 1.0068255155416814
# 0.06164282902689806

# %%
mean = np.mean([marketBM[date] for date in dates])

BMmarketpath = np.cumsum([np.sqrt(1/250)*(marketBM[date]-mean) for date in dates])

plt.plot(BMmarketpath)
plt.show()

# %%
Ymarket = np.cumsum([data["log_return"].loc[date] for date in dates])
Ymarket = np.exp(Ymarket)

# %% [markdown]
# Note that Ymarket is the same as data["close"] since
# $$ S_t = \exp\left( \sum_{i=1}^t \log(S_i/S_{i-1}) \right) $$

# %%
# Dimension of the path, in our case we have a 1 dimensional stock price
d=1
# Depth of the signature
M=70

def nilpotent(M):
    # Creates a Nillpotent matrix, with ones on the lower diagonal
    B = np.zeros((M,M))
    for i in range(1,M):
        B[i,i-1]=1.0
    return B

def canonical(i,M):
    # Generates M dimensional unit vectors
    e = np.zeros((M,1))
    e[i,0]=1.0
    return e

def randomAbeta(d,M):
    # Generates a random matrix A and a random vector b
    A = []
    beta = []
    for i in range(d):
        #B = 0.1*np.identity(M)+np.random.normal(0.0,.5,size=(M,M))
        B = np.random.normal(0.0,0.02,size=(M,M)) # 0.1 for scen-gen, 1.5 for SABR
        #B = np.random.permutation(B)
        #B = np.identity(M)
        #B = sp.linalg.sqrtm(np.matmul(B,np.transpose(B)))
        A = A + [B]
        beta = beta + [0.*canonical(i,M)+np.random.normal(0.0,0.03,size=(M,1))]
    return [A,beta]

Abeta = randomAbeta(d,M)
A = Abeta[0]
beta = Abeta[1]

def sigmoid(x):
    return np.tanh(x)

def reservoirfield(state,increment):
    value = np.zeros((M,1))
    for i in range(d):
        value = value + sigmoid(np.matmul(A[i],state) + beta[i])*increment[i]
    return value

# %% [markdown]
# The reservoir field simulates the following stochastic differential equation
# $$ dX_t = \sum_{i=0}^d \sigma(A_i X_t + b_i) du^{i}(t).$$
# In our case, since $d = 1$ we have
# $$ dX_t = \sigma(A X_t + b) du(t),$$
# where the increment is the underlying Brownian motion.

# %%
timehorizon = 1
dimensionR = M
timesteps = len(dates)-1

def reservoir(initialvalue, BMpath, scaling, k):
    reservoirpath = [canonical(k,dimensionR)*initialvalue]
    for i in range(timesteps):
        increment = [scaling*(BMpath[i+1]-BMpath[i])]
        reservoirpath = reservoirpath + [np.exp(-1.0*timehorizon/timesteps)*(reservoirpath[-1]+reservoirfield(reservoirpath[-1],increment))]
    return reservoirpath

# %% [markdown]
# The reservoir function of the above class does the following: it calculates the value
# $$ X_t = e^{-T/t}*(X_{t-1} + \sigma(A X_{t-1} + b)*C*dW(t)) $$
# for each $t \in \{0,1,...,T\}$ and $C \in \R$ a scaling factor, and stores the result in a list. The scaling $e^{-T/t}$ puts more weight on the more recent timestamps.

# %% [markdown]
# We want to learn the relation $W_t \mapsto X_t$. The problem is that when we try to learn this directly the machine models fail to learn this relation (see example below). What we then do, is, we write out $X_t$ in a Signature basis. Since this is very costly, we do a random projection which faciliates work enormously. Then we learn the relation of $X_t$, written out in this basis and the input $W_t$.\
# \
# Basically we want to calculate the signatures of the path $X_t$, but they are really expensive, so we compute a random projection of these signatures $\hat{X}_t$, which we can model by the above reservoir SDE and the underlying BM, and then we learn the relation between $\hat{X}_t$ and $X_t$ which will then work, since we are doing a regression in a basis.

# %% [markdown]
# #### Testing: Learn directly the relation between the BM and the SDE

# %%
Xtrain__ = BMmarketpath[:1800]
Ytrain__ = Ymarket[:1800]

Xtest__ = BMmarketpath[1800:]
Ytest__ = Ymarket[1800:]

# %%
print(Xtrain__.shape, Ytrain__.shape)
# Out:
# (1800,) (1800,)

# %%
modelNN = Sequential([
    Dense(128, activation='relu', input_shape=(1,)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'), 
    Dense(1, activation='linear') 
])

modelNN.compile(optimizer='adam', loss='mse', metrics=['mae'])

history = modelNN.fit(Xtrain__, Ytrain__, epochs=100, batch_size=32)

plt.plot(Xtrain__,'g')
plt.plot(modelNN.predict(Xtrain__),'r')
plt.plot(Ytrain__,'b')
plt.show()
# Out:
# Epoch 1/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7860 - mae: 1.8231
# Epoch 2/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5688 - mae: 0.6280
# Epoch 3/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5269 - mae: 0.5995
# Epoch 4/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5032 - mae: 0.5795
# Epoch 5/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4829 - mae: 0.5691
# Epoch 6/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5050 - mae: 0.5858
# Epoch 7/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4996 - mae: 0.5732
# Epoch 8/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4801 - mae: 0.5617
# Epoch 9/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5302 - mae: 0.5879
# Epoch 10/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5274 - mae: 0.5906
# Epoch 11/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5198 - mae: 0.5938
# Epoch 12/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5339 - mae: 0.5873
# Epoch 13/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5351 - mae: 0.5965
# Epoch 14/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5171 - mae: 0.5801
# Epoch 15/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5387 - mae: 0.5913
# Epoch 16/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5441 - mae: 0.5888
# Epoch 17/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5289 - mae: 0.5837
# Epoch 18/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5161 - mae: 0.5785
# Epoch 19/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4970 - mae: 0.5623
# Epoch 20/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5086 - mae: 0.5703
# Epoch 21/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5228 - mae: 0.5731
# Epoch 22/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5107 - mae: 0.5761
# Epoch 23/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4885 - mae: 0.5593
# Epoch 24/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5156 - mae: 0.5727
# Epoch 25/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5063 - mae: 0.5725
# Epoch 26/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4957 - mae: 0.5674
# Epoch 27/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5319 - mae: 0.5883
# Epoch 28/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4692 - mae: 0.5527
# Epoch 29/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5319 - mae: 0.5918
# Epoch 30/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5080 - mae: 0.5698
# Epoch 31/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4987 - mae: 0.5623
# Epoch 32/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5136 - mae: 0.5765
# Epoch 33/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5024 - mae: 0.5649
# Epoch 34/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5175 - mae: 0.5720
# Epoch 35/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5162 - mae: 0.5797
# Epoch 36/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5080 - mae: 0.5715
# Epoch 37/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4890 - mae: 0.5611
# Epoch 38/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5403 - mae: 0.5865
# Epoch 39/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5164 - mae: 0.5786
# Epoch 40/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5068 - mae: 0.5729
# Epoch 41/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5235 - mae: 0.5796
# Epoch 42/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4804 - mae: 0.5495
# Epoch 43/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5049 - mae: 0.5591
# Epoch 44/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5150 - mae: 0.5766
# Epoch 45/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5032 - mae: 0.5650
# Epoch 46/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5183 - mae: 0.5770
# Epoch 47/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4843 - mae: 0.5551
# Epoch 48/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5084 - mae: 0.5679
# Epoch 49/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4847 - mae: 0.5539
# Epoch 50/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4912 - mae: 0.5603
# Epoch 51/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5110 - mae: 0.5778
# Epoch 52/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5183 - mae: 0.5791
# Epoch 53/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4842 - mae: 0.5587
# Epoch 54/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4771 - mae: 0.5521
# Epoch 55/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5071 - mae: 0.5720
# Epoch 56/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5066 - mae: 0.5689
# Epoch 57/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5056 - mae: 0.5672
# Epoch 58/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5112 - mae: 0.5730
# Epoch 59/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5130 - mae: 0.5743
# Epoch 60/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5488 - mae: 0.5868
# Epoch 61/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5329 - mae: 0.5791
# Epoch 62/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5389 - mae: 0.5818
# Epoch 63/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4831 - mae: 0.5589
# Epoch 64/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5013 - mae: 0.5651
# Epoch 65/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5148 - mae: 0.5749
# Epoch 66/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5014 - mae: 0.5632
# Epoch 67/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5253 - mae: 0.5799
# Epoch 68/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5138 - mae: 0.5688
# Epoch 69/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5097 - mae: 0.5646
# Epoch 70/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4911 - mae: 0.5583
# Epoch 71/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5584 - mae: 0.5975
# Epoch 72/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5198 - mae: 0.5629
# Epoch 73/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5023 - mae: 0.5648
# Epoch 74/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5216 - mae: 0.5701
# Epoch 75/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5222 - mae: 0.5736
# Epoch 76/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5049 - mae: 0.5671
# Epoch 77/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4865 - mae: 0.5561
# Epoch 78/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4826 - mae: 0.5509
# Epoch 79/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4958 - mae: 0.5533
# Epoch 80/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5249 - mae: 0.5776
# Epoch 81/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5192 - mae: 0.5724
# Epoch 82/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5009 - mae: 0.5569
# Epoch 83/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5498 - mae: 0.5914
# Epoch 84/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4873 - mae: 0.5522
# Epoch 85/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5106 - mae: 0.5667
# Epoch 86/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5224 - mae: 0.5745
# Epoch 87/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4972 - mae: 0.5536
# Epoch 88/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4740 - mae: 0.5453
# Epoch 89/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5073 - mae: 0.5699
# Epoch 90/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5291 - mae: 0.5753
# Epoch 91/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5151 - mae: 0.5700
# Epoch 92/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5168 - mae: 0.5696
# Epoch 93/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5234 - mae: 0.5698
# Epoch 94/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4984 - mae: 0.5543
# Epoch 95/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4949 - mae: 0.5536
# Epoch 96/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4913 - mae: 0.5561
# Epoch 97/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5072 - mae: 0.5588
# Epoch 98/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4964 - mae: 0.5613
# Epoch 99/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5024 - mae: 0.5605
# Epoch 100/100
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5134 - mae: 0.5689
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
f,p=plt.subplots(1,1,figsize=(6,6),sharey=False)

p.plot(modelNN.predict(Xtest__),'b')
p.plot(Ytest__,'g')
plt.show()
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# #### My model

# %%
# Initial value of the Google close price
initialvalue = Ymarket[0]
# Convert the underlying BM to a list
BMmarketpathlist = [BMmarketpath[i] for i in range(len(dates))]
X = reservoir(initialvalue, BMmarketpathlist, 0.5, 0)
# Xdata has shape (num_days, depth signature)
Xdata = np.squeeze(X)

Ytrain = Ymarket[:1800]
Xtrain = Xdata[:1800]

# %%
Xtrain.shape
# Out:
# (1800, 70)

# %%
modelNN = Sequential([
    Dense(128, activation='relu', input_shape=(Xtrain.shape[1],)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'), 
    Dense(1, activation='linear') 
])

modelNN.compile(optimizer='adam', loss='mse', metrics=['mae'])

history = modelNN.fit(Xtrain, Ytrain, epochs=100, batch_size=32)

plt.plot(Xtrain,'g')
plt.plot(modelNN.predict(Xtrain),'r')
plt.plot(Ytrain,'b')
plt.show()

# %%
f,p=plt.subplots(1,1,figsize=(6,6),sharey=False)

p.plot(modelNN.predict(Xdata[1800:]),'b')
p.plot(Ymarket[1800:],'g')
plt.show()

# %%
lm = linear_model.Ridge(alpha=0.05)#LinearRegression()
modelR = lm.fit(Xtrain,Ytrain)
plt.plot(modelR.predict(Xtrain),'r')
plt.plot(Ytrain,'b')
plt.show()
#modelR.score(Xtrain,Ymarkettrain)
#modelR.coef_

# %%
f,p=plt.subplots(1,1,figsize=(6,6),sharey=False)

p.plot(modelR.predict(Xdata[1800:]),'b')
p.plot(Ymarket[1800:],'g')
plt.show()

# %% [markdown]
# #### Josef's model

# %%
# Initial value of the Google close price
initialvalue = 1.5 #Ymarket[0]
# Convert the underlying BM to a list
BMmarketpathlist = [BMmarketpath[i] for i in range(len(dates))]
X = reservoir(initialvalue, BMmarketpathlist, 0.5, 0)
# Xdata has shape (num_days, depth signature)
Xdata = np.squeeze(X)

initialvalue = 0.0
X1 = reservoir(initialvalue, BMmarketpathlist, 0.4, 0)
Xdata1=np.squeeze(X1)

initialvalue = -1.5
X2 = reservoir(initialvalue, BMmarketpathlist, 0.3, 0)
Xdata2 = np.squeeze(X2)

# %%
Ymarketdiff = np.diff(Ymarket,axis=0)
Ymarkettrain = np.concatenate((Ymarket[:1800],Ymarketdiff[:1800:1]),axis=0)
np.shape(Ymarkettrain)

# %%
Xdata = np.concatenate((Xdata,Xdata1,Xdata2),axis=1)
Xdatadiff = np.diff(Xdata,axis=0)
Xtrain=np.concatenate((Xdata[:1800],Xdatadiff[:1800:1]),axis=0)

# %%
# Wieso diff?

# %%
np.shape(Xtrain)

# %%
lm = linear_model.Ridge(alpha=0.05)#LinearRegression()
model = lm.fit(Xtrain,Ymarkettrain)
plt.plot(model.predict(Xtrain),'r')
plt.plot(Ymarkettrain,'b')
plt.show()
model.score(Xtrain,Ymarkettrain)
model.coef_

# %%
f,p=plt.subplots(1,1,figsize=(6,6),sharey=False)

p.plot(model.predict(Xdata[1800:]),'b')
p.plot(Ymarket[1800:],'g')
plt.show()
