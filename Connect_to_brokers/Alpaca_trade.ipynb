# %%
from alpaca.trading.client import TradingClient

api_key = "PKAG0XBVFXJPXPXBWPGW"
secret_key = "pjp69zCQBSUziTzXEjZ9DagW04sni7Jg99QKH6TH"

# paper=True enables paper trading
trading_client = TradingClient(api_key, secret_key, paper=True)

# %%
account = trading_client.get_account()

# %%
display(account)
# Out:
# {   'account_blocked': False,
#     'account_number': 'PA32YLFTTR17',
#     'accrued_fees': '0',
#     'buying_power': '200000',
#     'cash': '100000',
#     'created_at': datetime.datetime(2024, 11, 24, 10, 51, 49, 59218, tzinfo=TzInfo(UTC)),
#     'crypto_status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'currency': 'USD',
#     'daytrade_count': 0,
#     'daytrading_buying_power': '0',
#     'equity': '100000',
#     'id': UUID('ac6b2b79-2553-417e-945b-e1e2b1725774'),
#     'initial_margin': '0',
#     'last_equity': '100000',
#     'last_maintenance_margin': '0',
#     'long_market_value': '0',
#     'maintenance_margin': '0',
#     'multiplier': '2',
#     'non_marginable_buying_power': '100000',
#     'options_approved_level': 2,
#     'options_buying_power': '100000',
#     'options_trading_level': 2,
#     'pattern_day_trader': False,
#     'pending_transfer_in': None,
#     'pending_transfer_out': None,
#     'portfolio_value': '100000',
#     'regt_buying_power': '200000',
#     'short_market_value': '0',
#     'shorting_enabled': True,
#     'sma': '100000',
#     'status': <AccountStatus.ACTIVE: 'ACTIVE'>,
#     'trade_suspended_by_user': False,
#     'trading_blocked': False,
#     'transfers_blocked': False}

# %%
from alpaca.trading.requests import GetAssetsRequest
from alpaca.trading.enums import AssetClass

trading_client = TradingClient(api_key, secret_key)

# search for crypto assets
search_params = GetAssetsRequest(asset_class=AssetClass.CRYPTO)

assets = trading_client.get_all_assets(search_params)

# %%
print(assets)
# Out:
# [{   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('39d2df3b-4273-46a9-956d-c23634be1e38'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.057405281,
#     'min_trade_increment': 1e-09,
#     'name': 'Uniswap / US Dollar',
#     'price_increment': 0.001,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'UNI/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('38f8a0a4-399c-4f5a-8c0d-7435faef70d1'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.999000999,
#     'min_trade_increment': 1e-09,
#     'name': 'USDC/USD pair',
#     'price_increment': 0.0001,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'USDC/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('541b0d67-c2c7-4135-ac31-ff2aa6c0dd71'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.99889123,
#     'min_trade_increment': 1e-09,
#     'name': 'USD Tether / US Dollar',
#     'price_increment': 0.0001,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'USDT/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('6a521dc8-c56b-4096-bb84-66e0db2d155d'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.676589986,
#     'min_trade_increment': 1e-09,
#     'name': 'Tezos / US Dollar',
#     'price_increment': None,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'XTZ/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('9e853ba9-1eea-4226-8a39-c9995420e2c9'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 8.7188e-05,
#     'min_trade_increment': 1e-09,
#     'name': 'Yearn Finance / US Dollar',
#     'price_increment': 5.0,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'YFI/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('50960a81-1ec0-45b8-89dc-d6d3ab92f894'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 3.442340791,
#     'min_trade_increment': 1e-09,
#     'name': 'Basic Attention Token / US Dollar',
#     'price_increment': 2.5e-05,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'BAT/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('f0a05db3-5c93-4524-8a32-2f2b8d4f12fc'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.001877581,
#     'min_trade_increment': 1e-09,
#     'name': 'Bitcoin Cash / US Dollar',
#     'price_increment': 0.025,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'BCH/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('276e2673-764b-4ab6-a611-caf665ca6340'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 9.803e-06,
#     'min_trade_increment': 1e-09,
#     'name': 'Bitcoin  / US Dollar',
#     'price_increment': 1.0,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'BTC/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('19c466e7-e8f7-43e0-a8c5-f17ec9f5de8d'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.008176614,
#     'min_trade_increment': 1e-09,
#     'name': 'Litecoin / US Dollar',
#     'price_increment': 0.005,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'LTC/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('faf30512-0c0d-4ff8-a7a0-169c747d1e9c'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.033688636,
#     'min_trade_increment': 1e-09,
#     'name': 'Chainlink / US Dollar',
#     'price_increment': 0.0005,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'LINK/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('8588af33-3a8e-4a09-bb6c-ba4226dc7aff'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.002601734,
#     'min_trade_increment': 1e-09,
#     'name': 'Aave / US Dollar',
#     'price_increment': 0.01,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'AAVE/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('0515189d-1933-4a94-89ce-4e9a24356d58'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.018897947,
#     'min_trade_increment': 1e-09,
#     'name': 'Avalanche / US Dollar',
#     'price_increment': 0.0005,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'AVAX/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('0425de77-90d3-4ac9-b914-73423b4e42b8'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.840322011,
#     'min_trade_increment': 1e-09,
#     'name': 'Curve / US Dollar',
#     'price_increment': None,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'CRV/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('03e005f7-4bfc-4616-b1b0-225dd64074fa'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 2.434754661,
#     'min_trade_increment': 1e-09,
#     'name': 'Dogecoin / US Dollar',
#     'price_increment': 5e-07,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'DOGE/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('764fb9f4-14a1-4c93-bcf9-6a460029143d'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.11040379,
#     'min_trade_increment': 1e-09,
#     'name': 'Polkadot / US Dollar',
#     'price_increment': None,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'DOT/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('a1733398-6acc-4e92-af24-0d0667f78713'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.000255707,
#     'min_trade_increment': 1e-09,
#     'name': 'Ethereum / US Dollar',
#     'price_increment': 0.1,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'ETH/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('3e242d92-02c9-42d8-a2a1-e04f8b2f8860'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 3.516409324,
#     'min_trade_increment': 1e-09,
#     'name': 'The Graph / US Dollar',
#     'price_increment': 5e-05,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'GRT/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('90a83e2d-e574-404b-9344-74130736b71c'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.000481904,
#     'min_trade_increment': 1e-09,
#     'name': 'Maker / US Dollar',
#     'price_increment': 0.5,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'MKR/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('80d871ac-7a59-48b1-b71d-760d5a6876c6'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 35026.269702276,
#     'min_trade_increment': 1e-09,
#     'name': 'Shiba Inu / US Dollar',
#     'price_increment': 1e-08,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'SHIB/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('9226ef75-ba41-4a4b-a1b4-96e1a1b818f0'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.004454342,
#     'min_trade_increment': 1e-09,
#     'name': 'Solana / US Dollar',
#     'price_increment': 0.0025,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'SOL/USD',
#     'tradable': True}, {   'asset_class': <AssetClass.CRYPTO: 'crypto'>,
#     'attributes': [],
#     'easy_to_borrow': False,
#     'exchange': <AssetExchange.CRYPTO: 'CRYPTO'>,
#     'fractionable': True,
#     'id': UUID('ce414735-ba65-43c8-be76-7cb78ed2413d'),
#     'maintenance_margin_requirement': 100.0,
#     'marginable': False,
#     'min_order_size': 0.44810898,
#     'min_trade_increment': 1e-09,
#     'name': 'SushiSwap / US Dollar',
#     'price_increment': 0.0001,
#     'shortable': False,
#     'status': <AssetStatus.ACTIVE: 'active'>,
#     'symbol': 'SUSHI/USD',
#     'tradable': True}]

# %%
from alpaca.trading.requests import MarketOrderRequest
from alpaca.trading.enums import OrderSide, TimeInForce

trading_client = TradingClient(api_key, secret_key, paper=True)

# preparing orders
market_order_data = MarketOrderRequest(
                    symbol="SPY",
                    qty=0.023,
                    side=OrderSide.BUY,
                    time_in_force=TimeInForce.DAY
                    )

# Market order
market_order = trading_client.submit_order(
                order_data=market_order_data
               )
